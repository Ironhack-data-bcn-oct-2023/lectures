# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-aggregation" data-toc-modified-id="Data-aggregation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data aggregation</a></span><ul class="toc-item"><li><span><a href="#groupby" data-toc-modified-id="groupby-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>groupby</a></span><ul class="toc-item"><li><span><a href="#groupby-&amp;-aggregate" data-toc-modified-id="groupby-&amp;-aggregate-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>groupby &amp; aggregate</a></span></li></ul></li><li><span><a href="#Pivot-Tables" data-toc-modified-id="Pivot-Tables-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Pivot Tables</a></span></li><li><span><a href="#Differences-between-pivot-table-and-groupby-function" data-toc-modified-id="Differences-between-pivot-table-and-groupby-function-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Differences between pivot table and groupby function</a></span></li><li><span><a href="#crosstab" data-toc-modified-id="crosstab-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>crosstab</a></span></li></ul></li><li><span><a href="#Data-combination:-mixing-dataframes" data-toc-modified-id="Data-combination:-mixing-dataframes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data combination: mixing dataframes</a></span><ul class="toc-item"><li><span><a href="#Concat:-two-things-together" data-toc-modified-id="Concat:-two-things-together-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Concat: two things together</a></span><ul class="toc-item"><li><span><a href="#Concatenating-on-axis-0-(rows)" data-toc-modified-id="Concatenating-on-axis-0-(rows)-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Concatenating on axis 0 (rows)</a></span></li><li><span><a href="#Concatenating-on-axis-1-(columns)" data-toc-modified-id="Concatenating-on-axis-1-(columns)-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Concatenating on axis 1 (columns)</a></span></li></ul></li><li><span><a href="#Merge:-related-columns" data-toc-modified-id="Merge:-related-columns-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Merge: related columns</a></span><ul class="toc-item"><li><span><a href="#LEFT-Merge" data-toc-modified-id="LEFT-Merge-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>LEFT Merge</a></span></li><li><span><a href="#RIGHT-Merge" data-toc-modified-id="RIGHT-Merge-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>RIGHT Merge</a></span></li><li><span><a href="#INNER-Merge" data-toc-modified-id="INNER-Merge-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>INNER Merge</a></span></li><li><span><a href="#OUTER-Merge" data-toc-modified-id="OUTER-Merge-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>OUTER Merge</a></span></li></ul></li><li><span><a href="#Merging-&amp;-Concatenating-in-two-different-columns" data-toc-modified-id="Merging-&amp;-Concatenating-in-two-different-columns-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Merging &amp; Concatenating in two different columns</a></span><ul class="toc-item"><li><span><a href="#Concatenating-in-two-different-columns" data-toc-modified-id="Concatenating-in-two-different-columns-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Concatenating in two different columns</a></span></li><li><span><a href="#Merging-in-two-different-columns" data-toc-modified-id="Merging-in-two-different-columns-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Merging in two different columns</a></span></li></ul></li><li><span><a href="#Join:-relating-index" data-toc-modified-id="Join:-relating-index-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Join: relating index</a></span></li><li><span><a href="#Differences-between-join-&amp;-merge" data-toc-modified-id="Differences-between-join-&amp;-merge-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Differences between join &amp; merge</a></span></li></ul></li><li><span><a href="#Pandas-usual-methods" data-toc-modified-id="Pandas-usual-methods-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Pandas usual methods</a></span></li><li><span><a href="#Further-materials" data-toc-modified-id="Further-materials-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Further materials</a></span></li></ul></div>

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*6d5dw6dPhy4vBp2vRW6uzw.webp)

# %%
import pandas as pd
import numpy as np

# %%
# One table: group info by category, and check how much of something
    # organic -> average price
    # conventional -> average price
    
# groupby -> pivot table (excel)
# GROUPING based on CATEGORICAL VARIABLE
# To get a measure (a qtve variable) on each level of the category

# avg price (measure) per type of avocado (categorical)

# %% [markdown]
# ## Data aggregation

# %% [markdown]
# `groupby, pivot table & cross_tab`

# %% [markdown]
# ### groupby
# Pandas GroupBy is a powerful and versatile function in Python. It allows us to split your data into separate groups to perform calculations for better analysis.
# A DataFrame can be grouped on its rows (axis=0) or on its columns (axis=1). Once this is done, a function is applied to each group, producing a new value. Finally, the results of all those function applications are combined into a result object. The shape of the resulting object will usually depend on what is done with the data.

# %% [markdown]
# `df[subset].groupby(category).aggregation()`

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# %%
df = pd.read_csv("../datasets/employees.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 0      41       Yes      Travel_Rarely       1102                   Sales  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount
# 0                    1          2  Life Sciences              1  \
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours
# 0                  1  ...                         1            80  \
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear
# 0                    0                  8                      0  \
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole
# 0                  1               6                  4  \
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# Explore
    # info
   # describe 
    # shape
    # WITHIN COLUMNS
        # missing values
        # how many of each? -> value_counts() 
        # unique()
    # mean, min, max

# %% [markdown]
# `groupby the departments and their mean age`

# %%
# mean AGE per DEPARTMENT?
df.groupby("Department").aggregate({"Age":"mean"})
# Out:
#                               Age
# Department
# Human Resources         37.809524
# Research & Development  37.042664
# Sales                   36.542601

# %% [markdown]
# `groupby the departments and their maximum age`

# %%
df.groupby("Department").aggregate({"Age":"max"})
# Out:
#                         Age
# Department
# Human Resources          59
# Research & Development   60
# Sales                    60

# %% [markdown]
# `groupby the departments and their min age`

# %%
df.groupby("Department").aggregate({"Age":"min"})
# Out:
#                         Age
# Department
# Human Resources          19
# Research & Development   18
# Sales                    18

# %% [markdown]
# `groupby: 2+`: Different Education Fields and their Mean Salaries in each of the Department

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df["EducationField"].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df.columns = [i.lower().replace(" ", "") for i in df.columns]

# %%
df.sample()
# Out:
#      age attrition businesstravel  dailyrate              department
# 420   29        No  Travel_Rarely        986  Research & Development  \
#
#      distancefromhome  education educationfield  employeecount
# 420                 3          4        Medical              1  \
#
#      employeenumber  ...  relationshipsatisfaction standardhours
# 420             564  ...                         3            80  \
#
#      stockoptionlevel  totalworkingyears  trainingtimeslastyear
# 420                 0                 10                      2  \
#
#     worklifebalance  yearsatcompany yearsincurrentrole
# 420               3              10                  2  \
#
#      yearssincelastpromotion  yearswithcurrmanager
# 420                        0                     7
#
# [1 rows x 35 columns]

# %%
df["monthlyincome"].mean()
# Out:
# 6502.931292517007

# %%
type(df_new)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new["monthlyincome"]["mean"]
# Out:
# department              educationfield
# Human Resources         Human Resources     7241.148148
#                         Life Sciences       6914.062500
#                         Medical             6594.076923
#                         Other               5016.666667
#                         Technical Degree    3081.250000
# Research & Development  Life Sciences       6179.984091
#                         Medical             6539.223140
#                         Other               6278.687500
#                         Technical Degree    5760.819149
# Sales                   Life Sciences       7246.233333
#                         Marketing           7348.584906
#                         Medical             6377.227273
#                         Other               5398.733333
#                         Technical Degree    6066.294118
# Name: mean, dtype: float64

# %%
df_new["monthlyincome"]["new_col"] =  df_new["monthlyincome"]["mean"] * 100
# Out:
# /var/folders/pz/11hk3xjx34z9gw2tjzmjl4lm0000gn/T/ipykernel_30189/2516271992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["monthlyincome"]["new_col"] =  df_new["monthlyincome"]["mean"] * 100

# %%
df_new = df.groupby(["department", "educationfield"]).aggregate({"monthlyincome":["mean", "min", "max", "count"]})
df_new
# Out:
#                                         monthlyincome
#                                                  mean   min    max count
# department             educationfield
# Human Resources        Human Resources    7241.148148  1555  19636    27
#                        Life Sciences      6914.062500  2064  19717    16
#                        Medical            6594.076923  2109  18200    13
#                        Other              5016.666667  2991   7988     3
#                        Technical Degree   3081.250000  2564   4323     4
# Research & Development Life Sciences      6179.984091  1051  19999   440
#                        Medical            6539.223140  1009  19859   363
#                        Other              6278.687500  1951  19613    64
#                        Technical Degree   5760.819149  1274  19943    94
# Sales                  Life Sciences      7246.233333  1118  19847   150
#                        Marketing          7348.584906  1675  19845   159
#                        Medical            6377.227273  1052  19833    88
#                        Other              5398.733333  2121  10932    15
#                        Technical Degree   6066.294118  1091  16872    34

# %%
df_new["monthlyincome"]["new_col"] =  df_new["monthlyincome"]["mean"] * 100
# Out:
# /var/folders/pz/11hk3xjx34z9gw2tjzmjl4lm0000gn/T/ipykernel_30189/2516271992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["monthlyincome"]["new_col"] =  df_new["monthlyincome"]["mean"] * 100

# %%
# TO DO!!!: HOW TO ALSO INCLUDE A NEW COLUMN THAT IS THE TOTAL FOR THE SUBTOTALS GOTTEN BEFORE

# %%
df_new.index
# Out:
# MultiIndex([(       'Human Resources',  'Human Resources'),
#             (       'Human Resources',    'Life Sciences'),
#             (       'Human Resources',          'Medical'),
#             (       'Human Resources',            'Other'),
#             (       'Human Resources', 'Technical Degree'),
#             ('Research & Development',    'Life Sciences'),
#             ('Research & Development',          'Medical'),
#             ('Research & Development',            'Other'),
#             ('Research & Development', 'Technical Degree'),
#             (                 'Sales',    'Life Sciences'),
#             (                 'Sales',        'Marketing'),
#             (                 'Sales',          'Medical'),
#             (                 'Sales',            'Other'),
#             (                 'Sales', 'Technical Degree')],
#            names=['department', 'educationfield'])

# %%
# multiindex: https://pandas.pydata.org/docs/user_guide/advanced.html

# %% [markdown]
# `more fields`

# %% [markdown]
# #### groupby & aggregate

# %% [markdown]
# Another way to groupby with agg syntax
# https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.aggregate.html
#
# - mean
# - sum
# -count

# %% [markdown]
# Suppose we want to calculate the mean of column data1 using the labels of key1. There are several ways to do it. One is to access data1 and call groupby with the column (a String) in key1.
# The data (a Series) has been aggregated based on the group key, producing a new String that is now indexed by the unique values ​​of the key1 column. The resulting index has the name 'key1' because the DataFrame column `df['key1']` did.

# %%
# mean
# sum
# count
# min
# max
# stdeviation

# %%
# education field, hourly rate, department, stardar hours, age

# %%
df.groupby("age").aggregate({"monthlyincome":"mean"}) # average salary per age

# age: 
    # 18-19 , 21, 22
    # 18.5
    # 18.6
    
# create groups or changes
    # create new column: apply(lambda x: ....)
    # group by the categories and aggregate based on mean of income
# Out:
#      monthlyincome
# age
# 18     1518.375000
# 19     2075.000000
# 20     2539.363636
# 21     2491.461538
# 22     2950.000000
# 23     2515.357143
# 24     3243.923077
# 25     4144.769231
# 26     3531.487179
# 27     4190.416667
# 28     3904.833333
# 29     4584.411765
# 30     4814.850000
# 31     5525.391304
# 32     5092.459016
# 33     5500.500000
# 34     5269.220779
# 35     5425.282051
# 36     5590.913043
# 37     5853.860000
# 38     5721.586207
# 39     8183.357143
# 40     7700.947368
# 41     8379.825000
# 42     8074.847826
# 43     8444.937500
# 44     7114.333333
# 45     7811.219512
# 46    11457.969697
# 47     8931.416667
# 48     9344.789474
# 49     9952.875000
# 50    12697.166667
# 51     9632.473684
# 52    10606.888889
# 53    11564.157895
# 54    10875.833333
# 55    13204.181818
# 56     8248.357143
# 57     8803.000000
# 58    10705.785714
# 59     8038.100000
# 60    10268.000000

# %%
# education field, hourly rate, department, stardar hours, age

# %%
df["standardhours"].value_counts()
# Out:
# standardhours
# 80    1470
# Name: count, dtype: int64

# %%
# Q: prefixes in the columns?
# TO-DO: documentation

# %%
df.groupby(["department", "educationfield"]).aggregate({"hourlyrate":"mean", "standardhours":"mean", "age":"mean" })
# Out:
#                                          hourlyrate  standardhours        age
# department             educationfield
# Human Resources        Human Resources    60.888889           80.0  37.037037
#                        Life Sciences      61.625000           80.0  39.375000
#                        Medical            72.076923           80.0  39.846154
#                        Other              76.000000           80.0  34.666667
#                        Technical Degree   64.000000           80.0  32.500000
# Research & Development Life Sciences      66.570455           80.0  36.997727
#                        Medical            66.330579           80.0  37.242424
#                        Other              62.203125           80.0  36.187500
#                        Technical Degree   66.351064           80.0  37.063830
# Sales                  Life Sciences      68.153333           80.0  37.186667
#                        Marketing          66.150943           80.0  37.924528
#                        Medical            59.943182           80.0  34.727273
#                        Other              60.333333           80.0  32.000000
#                        Technical Degree   67.676471           80.0  33.941176

# %% [markdown]
# ### Pivot Tables

# %% [markdown]
# [groupby vs pivot table](https://towardsdatascience.com/a-comparison-of-groupby-and-pivot-in-pythons-pandas-module-527909e78d6b?source=userActivityShare-4c6d9a33c6-1674605913&_branch_match_id=1146490620103499300&_branch_referrer=H4sIAAAAAAAAA8soKSkottLXz8nMy9bLTU3JLM3VS87P1TfKCvCtKvOvCCpPAgAN4ht%2FIwAAAA%3D%3D)

# %% [markdown]
# ```pivot_table(df, values=None, index=None, columns=None, aggfunc='mean', ...)```

# %% [markdown]
# * We can create a spreadsheet-style pivot table as a DataFrame. The levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.

# %% [markdown]
# `pivot table`: the department and their mean ages

# %% [markdown]
# `pivot table`: the department and their max ages

# %% [markdown]
# `pivot table`: the department and their min ages

# %% [markdown]
# `pivot table`: the department and their median age

# %% [markdown]
# `multi-index pivot table`: Department and Education Field and check the maximum salary values of employees

# %% [markdown]
# ### Differences between pivot table and groupby function

# %% [markdown]
# `groupby`: team mean age by team abbreviation & season.

# %% [markdown]
# `pivot_table`: team mean age by team abbreviation & season.

# %% [markdown]
# ### crosstab

# %% [markdown]
# * Compute a simple cross tabulation of two (or more) factors. By default computes a frequency table of the factors unless an array of values and an aggregation function are passed. Usually used to see the frequency of two qualitative variables: how many times the value of one column happens in the other one

# %% [markdown]
# ```pd.crosstab(df[column1], df[column2])```

# %%
pd.crosstab(df["department"], df["educationfield"]) # default is the count
# Out:
# educationfield          Human Resources  Life Sciences  Marketing  Medical
# department
# Human Resources                      27             16          0       13  \
# Research & Development                0            440          0      363
# Sales                                 0            150        159       88
#
# educationfield          Other  Technical Degree
# department
# Human Resources             3                 4
# Research & Development     64                94
# Sales                      15                34

# %%
pd.crosstab(df["department"], df["educationfield"], df["monthlyincome"], aggfunc="mean") 
# same as previous pivot table / groupby
# df.groupby(["department", "educationfield"]).aggregate({"monthlyincome":"mean"})
# Out:
# educationfield          Human Resources  Life Sciences    Marketing
# department
# Human Resources             7241.148148    6914.062500          NaN  \
# Research & Development              NaN    6179.984091          NaN
# Sales                               NaN    7246.233333  7348.584906
#
# educationfield              Medical        Other  Technical Degree
# department
# Human Resources         6594.076923  5016.666667       3081.250000
# Research & Development  6539.223140  6278.687500       5760.819149
# Sales                   6377.227273  5398.733333       6066.294118

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Data combination: mixing dataframes

# %% [markdown]
# - https://realpython.com/pandas-merge-join-and-concat/
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ### Concat: two things together
# We join dataframes along axis 0 one below the other. Align columns by label.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',
                             sep='|', 
                             index_col='user_id')
df.sample()
# Out:
#          age gender occupation zip_code
# user_id
# 575       33      M  marketing    46032

# %%
# Concatenate dataframes: put them together
#  5 rows + 10 more rows
# side to side
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# #### Concatenating on axis 0 (rows)

# %%
df_1 = df.sample(frac=0.1)

# %%
df.sample()
# Out:
#          age gender occupation zip_code
# user_id
# 183       33      M  scientist    27708

# %%
df_1.shape
# Out:
# (94, 4)

# %% [markdown]
# #### Concatenating on axis 1 (columns)

# %%
df_2 = df.sample(frac=0.2)
print(df_2.shape)
df_2
# Out:
# (189, 4)
#          age gender  occupation zip_code
# user_id
# 94        26      M     student    71457
# 700       17      M     student    76309
# 47        53      M   marketing    07102
# 805       27      F       other    20009
# 411       34      M    educator    44691
# ...      ...    ...         ...      ...
# 622       25      M  programmer    14850
# 714       26      M    engineer    55343
# 780       49      M  programmer    94560
# 573       68      M     retired    48911
# 541       19      F     student    84302
#
# [189 rows x 4 columns]

# %%
concatenated_dataframe = pd.concat([df_1, df_2], axis=0)
concatenated_dataframe
# Out:
#          age gender  occupation zip_code
# user_id
# 549       42      M   scientist    45680
# 351       61      M    educator    49938
# 804       39      M    educator    61820
# 738       35      M  technician    95403
# 790       27      M  technician    80913
# ...      ...    ...         ...      ...
# 622       25      M  programmer    14850
# 714       26      M    engineer    55343
# 780       49      M  programmer    94560
# 573       68      M     retired    48911
# 541       19      F     student    84302
#
# [283 rows x 4 columns]

# %%
concatenated_dataframe.shape
# Out:
# (283, 4)

# %%
concatenated_dataframe_axis_1 = pd.concat([df_1, df_2], axis=1)
concatenated_dataframe_axis_1 #diagonal df on NaN
# Out:
#           age gender  occupation zip_code   age gender  occupation zip_code
# user_id
# 549      42.0      M   scientist    45680   NaN    NaN         NaN      NaN
# 351      61.0      M    educator    49938   NaN    NaN         NaN      NaN
# 804      39.0      M    educator    61820   NaN    NaN         NaN      NaN
# 738      35.0      M  technician    95403   NaN    NaN         NaN      NaN
# 790      27.0      M  technician    80913   NaN    NaN         NaN      NaN
# ...       ...    ...         ...      ...   ...    ...         ...      ...
# 622       NaN    NaN         NaN      NaN  25.0      M  programmer    14850
# 714       NaN    NaN         NaN      NaN  26.0      M    engineer    55343
# 780       NaN    NaN         NaN      NaN  49.0      M  programmer    94560
# 573       NaN    NaN         NaN      NaN  68.0      M     retired    48911
# 541       NaN    NaN         NaN      NaN  19.0      F     student    84302
#
# [261 rows x 8 columns]

# %% [markdown]
# ![sql joins](https://upload.wikimedia.org/wikipedia/commons/9/9d/SQL_Joins.svg)

# %% [markdown]
# ### Merge: related columns

# %% [markdown]
# [Merge()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) is most useful when you want to merge rows that share data.

# %%
from IPython.display import display_html

# %%
df1 = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


df2 = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

df3 = pd.DataFrame(
    {
        "key1": ["K90", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K5", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "Y": ["D0", "D70", "D2", "D5"],
    }
)

# %%
df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
display_html(df1_styler._repr_html_() + " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_17783" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17783_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_17783_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_17783_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_17783_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17783_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17783_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_17783_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_17783_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_17783_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_17783_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17783_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_17783_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_17783_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_17783_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_17783_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_17783_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_17783_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_17783_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_17783_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_17783_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17783_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_17783_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_17783_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_17783_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_564da" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_564da_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_564da_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_564da_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_564da_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_564da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_564da_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_564da_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_564da_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_564da_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_564da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_564da_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_564da_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_564da_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_564da_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_564da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_564da_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_564da_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_564da_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_564da_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_564da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_564da_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_564da_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_564da_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_564da_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# merge, default is inner

result = pd.merge(df1, df2)
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# #### LEFT Merge

# %%
left_merge = pd.merge(df1, df2, how="left")


df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
left_merge = left_merge.style.set_table_attributes("style='display:inline'").set_caption("left_merge")

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fea52" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fea52_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_fea52_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_fea52_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_fea52_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fea52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fea52_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_fea52_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_fea52_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_fea52_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_fea52_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fea52_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_fea52_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_fea52_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_fea52_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_fea52_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fea52_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_fea52_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_fea52_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_fea52_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_fea52_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fea52_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_fea52_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_fea52_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_fea52_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_8759a" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8759a_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_8759a_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_8759a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_8759a_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8759a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8759a_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_8759a_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_8759a_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_8759a_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_8759a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8759a_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_8759a_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_8759a_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_8759a_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_8759a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8759a_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_8759a_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_8759a_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_8759a_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_8759a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8759a_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_8759a_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_8759a_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_8759a_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(left_merge._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_12a82" style='display:inline'>
#   <caption>left_merge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12a82_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_12a82_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_12a82_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_12a82_level0_col3" class="col_heading level0 col3" >B</th>
#       <th id="T_12a82_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_12a82_level0_col5" class="col_heading level0 col5" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12a82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12a82_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_12a82_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_12a82_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_12a82_row0_col3" class="data row0 col3" >B0</td>
#       <td id="T_12a82_row0_col4" class="data row0 col4" >C0</td>
#       <td id="T_12a82_row0_col5" class="data row0 col5" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_12a82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12a82_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_12a82_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_12a82_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_12a82_row1_col3" class="data row1 col3" >B1</td>
#       <td id="T_12a82_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_12a82_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_12a82_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12a82_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_12a82_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_12a82_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_12a82_row2_col3" class="data row2 col3" >B2</td>
#       <td id="T_12a82_row2_col4" class="data row2 col4" >C1</td>
#       <td id="T_12a82_row2_col5" class="data row2 col5" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_12a82_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12a82_row3_col0" class="data row3 col0" >K1</td>
#       <td id="T_12a82_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_12a82_row3_col2" class="data row3 col2" >A2</td>
#       <td id="T_12a82_row3_col3" class="data row3 col3" >B2</td>
#       <td id="T_12a82_row3_col4" class="data row3 col4" >C2</td>
#       <td id="T_12a82_row3_col5" class="data row3 col5" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_12a82_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12a82_row4_col0" class="data row4 col0" >K2</td>
#       <td id="T_12a82_row4_col1" class="data row4 col1" >K1</td>
#       <td id="T_12a82_row4_col2" class="data row4 col2" >A3</td>
#       <td id="T_12a82_row4_col3" class="data row4 col3" >B3</td>
#       <td id="T_12a82_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_12a82_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### RIGHT Merge

# %%
right_merge = pd.merge(df1, df2, how="right")


df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
right_merge = right_merge.style.set_table_attributes("style='display:inline'").set_caption("right_merge")

display_html(df1_styler._repr_html_() + " " + df2_styler._repr_html_(),raw=True)

# %%
display_html(right_merge._repr_html_(), raw=True)

# %% [markdown]
# #### INNER Merge

# %%
inner_merge = pd.merge(df1, df2, how="inner")


df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
inner_merge = inner_merge.style.set_table_attributes("style='display:inline'").set_caption("inner_merge")

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)

# %%
display_html(inner_merge._repr_html_(), raw=True)

# %% [markdown]
# #### OUTER Merge

# %%
outer_merge = pd.merge(df1, df2, how="outer")

df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
outer_merge = outer_merge.style.set_table_attributes("style='display:inline'").set_caption("outer_merge")

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)

# %%
display_html(outer_merge._repr_html_(), raw=True)

# %% [markdown]
# ### Merging & Concatenating in two different columns

# %%
df1_docs = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2_docs = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

# %%
df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)

# %% [markdown]
# #### Concatenating in two different columns

# %%
concat_docs = pd.concat([df1_docs, df2_docs], axis=1, keys=["1st table", "2nd table"])

df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')
merge_styler = concat_docs.style.set_table_attributes("style='display:inline'").set_caption('concat_docs')

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)

# %%
display_html(merge_styler._repr_html_(), raw=True)

# %% [markdown]
# #### Merging in two different columns

# %%
df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)

# %%
merge_docs = df1_docs.merge(df2_docs, left_on='lkey', right_on='rkey', suffixes = ["_fromleft", "_fromright"])

# %%
merge_docs = df1_docs.merge(df2_docs, left_on='lkey', right_on='rkey', suffixes = ["_from_left", "_from_right"])


df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')
merge_styler = merge_docs.style.set_table_attributes("style='display:inline'").set_caption('merge_docs')

display_html(df1_styler._repr_html_() + " " + df2_styler._repr_html_(), raw=True)

# %%
display_html(merge_styler._repr_html_(), raw=True)

# %%
# suffixes: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
# concat: putting things together
# join/merge: putting things together THAT ARE RELATED
    # related info in the same place -> reduces redundancy

# %% [markdown]
# ### Join: relating index
# The join, unlike the merge, will join the dataframes and where there are no records in the "index" it will put NaN

# %%
# PANDAS
    # MERGE IN PANDAS: targeting COLUMNS to put columns together
    # JOIN IN PANDAS: putting things together based on the INDEX


# MYSQL: join (cols)

# %%
import numpy as np
import pandas as pd   
from IPython.display import display_html

# %%
left_df = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)


right_df = pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)

# %%
df1_styler = left_df.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = right_df.style.set_table_attributes("style='display:inline'").set_caption('Right table')

display_html(df1_styler._repr_html_()+ df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7d109" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d109_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7d109_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d109_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_7d109_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_7d109_row0_col1" class="data row0 col1" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_7d109_level0_row1" class="row_heading level0 row1" >K1</th>
#       <td id="T_7d109_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_7d109_row1_col1" class="data row1 col1" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_7d109_level0_row2" class="row_heading level0 row2" >K2</th>
#       <td id="T_7d109_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_7d109_row2_col1" class="data row2 col1" >B2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dc42e" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc42e_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_dc42e_level0_col1" class="col_heading level0 col1" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc42e_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_dc42e_row0_col0" class="data row0 col0" >C0</td>
#       <td id="T_dc42e_row0_col1" class="data row0 col1" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_dc42e_level0_row1" class="row_heading level0 row1" >K2</th>
#       <td id="T_dc42e_row1_col0" class="data row1 col0" >C2</td>
#       <td id="T_dc42e_row1_col1" class="data row1 col1" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_dc42e_level0_row2" class="row_heading level0 row2" >K3</th>
#       <td id="T_dc42e_row2_col0" class="data row2 col0" >C3</td>
#       <td id="T_dc42e_row2_col1" class="data row2 col1" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = left_df.join(right_df, how="left")

#Rendering the df's in the same line. No need to learn this code

df1_styler = left_df.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = right_df.style.set_table_attributes("style='display:inline'").set_caption('Right table')
df1_df2_merged = result.style.set_table_attributes("style='display:inline'").set_caption('JOIN')

display_html(df1_styler._repr_html_()+ df2_styler._repr_html_() + df1_df2_merged._repr_html_(), raw=True)
#display_html(df1_styler._repr_html_()+ df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_71561" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71561_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_71561_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71561_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_71561_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_71561_row0_col1" class="data row0 col1" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_71561_level0_row1" class="row_heading level0 row1" >K1</th>
#       <td id="T_71561_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_71561_row1_col1" class="data row1 col1" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_71561_level0_row2" class="row_heading level0 row2" >K2</th>
#       <td id="T_71561_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_71561_row2_col1" class="data row2 col1" >B2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fd89e" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd89e_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_fd89e_level0_col1" class="col_heading level0 col1" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd89e_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_fd89e_row0_col0" class="data row0 col0" >C0</td>
#       <td id="T_fd89e_row0_col1" class="data row0 col1" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_fd89e_level0_row1" class="row_heading level0 row1" >K2</th>
#       <td id="T_fd89e_row1_col0" class="data row1 col0" >C2</td>
#       <td id="T_fd89e_row1_col1" class="data row1 col1" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_fd89e_level0_row2" class="row_heading level0 row2" >K3</th>
#       <td id="T_fd89e_row2_col0" class="data row2 col0" >C3</td>
#       <td id="T_fd89e_row2_col1" class="data row2 col1" >D3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a4f8a" style='display:inline'>
#   <caption>JOIN</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4f8a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a4f8a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a4f8a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_a4f8a_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4f8a_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_a4f8a_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_a4f8a_row0_col1" class="data row0 col1" >B0</td>
#       <td id="T_a4f8a_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_a4f8a_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_a4f8a_level0_row1" class="row_heading level0 row1" >K1</th>
#       <td id="T_a4f8a_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_a4f8a_row1_col1" class="data row1 col1" >B1</td>
#       <td id="T_a4f8a_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a4f8a_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4f8a_level0_row2" class="row_heading level0 row2" >K2</th>
#       <td id="T_a4f8a_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_a4f8a_row2_col1" class="data row2 col1" >B2</td>
#       <td id="T_a4f8a_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_a4f8a_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Differences between join & merge

# %% [markdown]
# <figure class="wp-block-table is-style-stripes"><table class="has-fixed-layout"><thead><tr><th><strong>Join Feature</strong></th><th class="has-text-align-center" data-align="center"><strong>join()</strong></th><th class="has-text-align-center" data-align="center"><strong>merge()</strong></th></tr></thead><tbody><tr><td>inner</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>left</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>right</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>outer</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>cross</td><td class="has-text-align-center" data-align="center">X</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Join on Indices</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Join on Columns</td><td class="has-text-align-center" data-align="center">X</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Left on column, right on index</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Left on index, right on column</td><td class="has-text-align-center" data-align="center">X</td><td class="has-text-align-center" data-align="center">Yes</td></tr></tbody></table>

# %%
# PUTTING THINGS TOGETHER
    # Concat
        # phisically putting things side by side
        # up-down: axis=0
        # left& right (diagonal of nan): axis=1
    # Merge
        # based on: common keys/COLS
    # Join
        # based on: common index
        
    # Inner, left & right
        # left vs right?: 
        # inner: you want no missing values

# Pivot tables-groupbys / crosstabs
    # GOAL
    # Grouping by categorical to aggregate on qtve
        # count on categorical (aggregate on categorical if you count), the rows, not the values
        
# When grouping: from less to more categories (readability)

# %% [markdown]
# ## Pandas usual methods
# ```python
# df.head() # prints the head, default 5 rows
# df.tail() # set the tail, default 5 rows
# df.describe() # statistical description
# df.info() # df information
# df.columns # show column
# df.index # show index
# df.dtypes # show column data types
# df.plot() # make a plot
# df.hist() # make a histogram
# df.col.value_counts() # counts the unique values ​​of a column
# df.col.unique() # returns unique values ​​from a column
# df.copy() # copies the df
# df.drop() # remove columns or rows (axis=0,1)
# df.dropna() # remove nulls
# df.fillna() # fills nulls
# df.shape # dimensions of the df
# df._get_numeric_data() # select numeric columns
# df.rename() # rename columns
# df.str.replace() # replace columns of strings
# df.astype(dtype='float32') # change the data type
# df.iloc[] # locate by index
# df.loc[] # locate by element
# df.transpose() # transposes the df
# df.T
# df.sample(n, frac) # sample from df
# df.col.sum() # sum of a column
# df.col.max() # maximum of a column
# df.col.min() # minimum of one column
# df[col] # select column
# df.col
# df.isnull() # null values
# df.isna()
# df.notna() # not null values
# df.drop_duplicates() # remove duplicates
# df.reset_index(inplace=True) # reset the index and overwrite
# ```

# %% [markdown]
# ## Further materials
#
# * [Read the docs!](https://pandas.pydata.org/pandas-docs/stable/index.html)
# * [Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * [Exercises to practice](https://github.com/guipsamora/pandas_exercises)
# * [More on merge, concat, and join](https://realpython.com/pandas-merge-join-and-concat/#pandas-join-combining-data-on-a-column-or-index). And [even more!](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
