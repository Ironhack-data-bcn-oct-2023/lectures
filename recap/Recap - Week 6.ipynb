# %%
# WEEK-6
    # 9oct- 17 nov

# 0. Git & bash
    # code organization: encapsulation & modularization
    # docstrings & comments
        # pseudocode
    # best practices (refactor things, one function does one thing)
    # README!!!!

# 1. Extraction
    # web scrapping
        # selenium
    # APIs
    # mongoDB
    # SQL
    
# 2. Exploration
    # Python & visualization libraries
    
# 3. Transformation
    # Python: pandas
    # Tableau: calcualted fields

    
# 4. Visualization & reporting

    # Python: seaborn, matplotlib, seaborn, plotly 
    # Tableau
    # Maps: geothingies

# Statistics
    # Distribution: where the values are placed along the range of the variable
       # type variable? qtve -> bell
            
    # Plot - Distribution of a categorical variable?: countplot
    # p_value: the value to test hypotheses -> accept / reject
        # H0: null hypothesis. usually it's formulated in "no difference" terms
        # H1: alternative hypothesis. usually it's: there's a difference
        
    # if p_value < alpha:
        # alpha: threshold -> make decisions by comparing the p_value

    # two-tailed test: 
        # threshold (alpha): alpha for both sides
        # when two and when one?
            # you don't which way it can go
            
    # barplot vs histogram: how do we know?
        # hist: continous, there's a progression in the X axis
        # barplot: discrete / categorical variable, X axis, we don't care as much
        
    # mean vs median
        # both are central tendency indicators
        # median is not affectred by extreme values (outliers)
        # mean more used
        # normal distribution: mean & stdev
            # two parameters
                # the percentage of data within 
                    # mean + 1std: 68ish
                    # mean + 2std: 95ish
                    # mean + 3stdv: 99ish
                # not skewed, not kurtosis, bell shaped, symmetric
        # stdev?
            # mean of 25k and stdev 5k € -> 60k
            # range where most of our values are
            # Error -> how wrong on average you'll be by guessing any number through the mean
                # -6k
                # +3k
                # avg of the error: 5k
                
            # 25k mean, 200€ euros, 25k ,25.200, 24.800, ....
                # weird: to see salaries that are 35, 20, 21
                # range where most values are: +/- 5k
                
           # the higher the stdev (range) -> the wider it is t he ditribution
            # it depends on the amount of data: 
                # the more data, the stdev tends to go a bit lower
                # if it's normal
                    # the bigger the sample -> the more likely you're gonna get something around the middle
                       # in the middle (-/+ 1 stdev) 
                    
        # z-test, t-test, ANOVA (ANalysis Of VAriance)
            # stdev: known or not known
            # mean
            # independant groups (men/women) or sample to a population (kids)
            # amount of data
            
        # one variable (qtve)
           # plot: HISTOGRAM
                # skewness (+/-): 
                    # normal (0)
                    # +: tail goes positive. more info on the left. there's more variance to the right
                    # -: tail goes negative. more info on the right. there's more variance to the left
                
           # not plots: 
            # Central tendency: (mean, median, mode)
            # Variance/Stdev
            # Quartiles: proportion/distribution
                # outliers
                
            
         
        # two variables (qtve)
            # plots: scatterplot
            # not plots
                # covariance / correlation
                
# Machine learning & final project
# AWS Cloud practitioner, Amazon web services, data engineers
