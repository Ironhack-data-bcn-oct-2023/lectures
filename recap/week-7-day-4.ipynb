# %%
# RECAP 

# Machine learning
    # process -> input (df) -> relationship between vars -> predict based on new vars
    # ML is subset of AI -> vars -> learns without explicitly told the rules
       # it finds the ifs itself
    # we use the model
        # the model itself (machine) finds the pattern
    # used to predict
    # Types of Machine learning
        # supervised: predcit values / categories
            # give tags (target) or ground truth to the model
            
        # unsupervised
            # groups / clusters / segments
            
        # reinforcement
            # to die until surviving
            # it learns based on the output: trial and error
    
# AI > ML(supervised, unsupervised, reinforcement) > DL (neural networks)
    # NN: https://www.activestate.com/resources/quick-reads/how-to-create-a-neural-network-in-python-with-and-without-keras/

    # METRICS to evaluate the model
        # MAE: Mean Absolute Error 
        # MSE: Mean Squared Error
        # RMSE: Root Mean Squared Error
        # r2: r_squared, coefficient of determination
        
        # We look at all of them at once
            # MAE & RMSE: both in the unit/scale of the target variable
               # goal: as low as possible 
            # r2: range 0-1
                # as close to 1 as possible
                # sus.ly close?: overfitting
                
        # OVERFITTING
            # Adjusts very well to your own data, but not with new data
                # you're loosing generalization power
                # it only works for you, not for anyone else
                # you cannot generalize that model to other data
            # Bias / variance tradeoff:
                # either too good for your data
                # or too good for new data
                # balance: in between for both
                
            # How to prevent it
                # train/test split, test_size = 0.2
                    # X_train: 80% of rows of all the features
                    # X_test: 20% of rows of all the features
                    # y_train: 80% of rows of all the target / dependant
                    # y_test: 20% of rows of all the target / dependant
                   
                    # y_pred: 20% of predicted data based on X_test
                    
                    # Train: to fit the model, find the equation
                    # Test: to evaluate the model
                        # metrics: y_pred(X_test) - y_test
                    
                    # How can I know if my model is overfitting?
                        # compare r2: training & test
                            # r2 of training is higher than r2 in test
                            # 
                    
                
                # cross-validation
